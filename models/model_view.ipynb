# %%
import joblib
# Load the model
loaded_model = joblib.load('time_series_model.pkl')

# %%
# Make predictions using the loaded model
forecast = loaded_model.forecast(steps=30)  # Forecast next 30 periods

# %%
print(forecast)
# Out:
# 2023-05-13    1642.688480
# 2023-05-20    1610.278952
# 2023-05-27    1660.517304
# 2023-06-03    1682.042990
# 2023-06-10    1685.875171
# 2023-06-17    1695.320805
# 2023-06-24    1638.306938
# 2023-07-01    1696.098991
# 2023-07-08    1662.825418
# 2023-07-15    1714.401817
# 2023-07-22    1736.498565
# 2023-07-29    1740.432272
# 2023-08-05    1750.127972
# 2023-08-12    1691.600817
# 2023-08-19    1750.926748
# 2023-08-26    1716.771227
# 2023-09-02    1769.713371
# 2023-09-09    1792.392957
# 2023-09-16    1796.430280
# 2023-09-23    1806.381192
# 2023-09-30    1746.309530
# 2023-10-07    1807.200982
# 2023-10-14    1772.145343
# 2023-10-21    1826.481341
# 2023-10-28    1849.755714
# 2023-11-04    1853.898776
# 2023-11-11    1864.110121
# 2023-11-18    1802.462271
# 2023-11-25    1864.951354
# 2023-12-02    1828.977159
# Freq: W-SAT, dtype: float64
